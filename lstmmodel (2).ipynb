# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Embedding, Dense,Input,Concatenate
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.optimizers import SGD,Adam
import pandas as pd

# %%
df = pd.read_csv("D:/public_dat/train.csv")
df['Sentence'] = df['Sentence'].str.lower()

# %%
df.head()
# Out:
#    Id                                           Sentence            Entity_1  \
# 0   1  rising interest rates affects borrowing costs ...      Interest Rates
# 1   3  market volatility affects traders by leading t...   Market Volatility
# 2   4  strong corporate earnings affect shareholders ...  Corporate Earnings
# 3   5  regulatory changes affect financial institutio...  Regulatory Changes
# 4   6  investor behavior affects market trends and as...   Investor Behavior
#
#                  Entity_2 Relation
# 0               borrowers  affects
# 1                 Traders  affects
# 2            Shareholders  affects
# 3  Financial Institutions  affects
# 4           Market Trends  affects

# %%
df['Sentence']
# Out:
# 0       rising interest rates affects borrowing costs ...
# 1       market volatility affects traders by leading t...
# 2       strong corporate earnings affect shareholders ...
# 3       regulatory changes affect financial institutio...
# 4       investor behavior affects market trends and as...
#                               ...
# 7687    sharp, which sells aquos smartphones, fell zer...
# 7688    short gross sales come when an investor sells ...
# 7689    homeowners have a good chance of keeping their...
# 7690    german broker lang & schwarz tradecenter ag, w...
# 7691    global funds sold more south korean stocks tha...
# Name: Sentence, Length: 7692, dtype: object

# %%
sentences=[]
for jok in df['Sentence']:
    sentences.append(jok)
word1=[]
for jok in df['Entity_1']:
    word1.append(jok)
word2=[]
for jok in df['Entity_2']:
    word2.append(jok)
relations=[]
for jok in df['Relation']:
    relations.append(jok)
    
# Separate data into input (sentences) and output (relations)
#sentences = np.array(sentences)
#word1 = np.array([df['Entity_1']])
#word2 = np.array([df['Entity_2']])
#relations = np.array([df['Relation']])
#sentences=sentences.flatten()
#word1=word1.flatten()
#word2=word2.flatten()
#relations=relations.flatten()
#print(relations)
# Tokenize sentences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences + word1 + word2)
vocab_size = len(tokenizer.word_index) + 1

# Encode sentences and relations
X_sentences = tokenizer.texts_to_sequences(sentences)
X_word1 = tokenizer.texts_to_sequences(word1)
X_word2 = tokenizer.texts_to_sequences(word2)
max_len = 256 #max(len(seq) for seq in X_sentences)
X_sentences = pad_sequences(X_sentences, maxlen=max_len)
X_word1 = pad_sequences(X_word1, maxlen=1)
X_word2 = pad_sequences(X_word2, maxlen=1)
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(relations)  # Assuming relations are categorical strings

# %%
# Split data into train and test sets
X_sentences_train, X_sentences_test, X_word1_train, X_word1_test, X_word2_train, X_word2_test, y_train, y_test = train_test_split(X_sentences, X_word1, X_word2, y, test_size=0.1, random_state=6)

# Define LSTM model with named input layers
embedding_dim = 150
num_classes = len(set(relations))

input_sentences = Input(shape=(max_len,), name='input_sentences')
input_word1 = Input(shape=(1,), name='input_word1')
input_word2 = Input(shape=(1,), name='input_word2')

embedding_layer = Embedding(input_dim=vocab_size, output_dim=embedding_dim)
lstm_layer = LSTM(units=256, dropout=0.0, recurrent_dropout=0.0)
lstm_layer2 = LSTM(units=128, dropout=0.0, recurrent_dropout=0.0)
lstm_layer3 = LSTM(units=64, dropout=0.0, recurrent_dropout=0.0)
dense_layer = Dense(num_classes, activation='softmax')

embedding_sentences = embedding_layer(input_sentences)
embedding_word1 = embedding_layer(input_word1)
embedding_word2 = embedding_layer(input_word2)

lstm_output_sentences = lstm_layer(embedding_sentences)
embedding_layer2 = Embedding(input_dim=vocab_size, output_dim=embedding_dim)
embedding_sentences2 = embedding_layer2(lstm_output_sentences)
lstm_output_word1 = lstm_layer2(embedding_sentences2)
embedding_layer3 = Embedding(input_dim=vocab_size, output_dim=embedding_dim)
embedding_sentences3 = embedding_layer2(lstm_output_word1)
lstm_output_word2 = lstm_layer3(embedding_sentences3)
lstm_output_word12 = lstm_layer(embedding_word1)
lstm_output_word22 = lstm_layer(embedding_word2)

concatenated = Concatenate()([lstm_output_sentences,lstm_output_word1,lstm_output_word2])
output = dense_layer(concatenated)

# %%
#print("Shape of X_sentences_train:", X_sentences_train.shape)
#print("Shape of X_sentences_test:", X_sentences_test.shape)
#print(X_sentences_train)
#max_len
print(output)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 12), dtype=tf.float32, name=None), name='dense_8/Softmax:0', description="created by layer 'dense_8'")

# %%
model = Model(inputs=[input_sentences], outputs=output)

# Compile the model
learning_rate = 0.001
beta_1 = 0.9
beta_2 = 0.999
epsilon = 1e-7
decay = 0.0
optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon, decay=decay)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit({"input_sentences": X_sentences_train}, y_train, epochs=10, batch_size=20, validation_split=0.2)

# Evaluate the model
loss, accuracy = model.evaluate({"input_sentences": X_sentences_test}, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/10
# 277/277 [==============================] - 19s 56ms/step - loss: 2.1636 - accuracy: 0.2380 - val_loss: 1.7633 - val_accuracy: 0.3870
# Epoch 2/10
# 277/277 [==============================] - 15s 53ms/step - loss: 0.9667 - accuracy: 0.6932 - val_loss: 0.7557 - val_accuracy: 0.7957
# Epoch 3/10
# 277/277 [==============================] - 15s 53ms/step - loss: 0.4077 - accuracy: 0.8922 - val_loss: 0.6650 - val_accuracy: 0.8455
# Epoch 4/10
# 277/277 [==============================] - 15s 54ms/step - loss: 0.2397 - accuracy: 0.9361 - val_loss: 0.6293 - val_accuracy: 0.8462
# Epoch 5/10
# 277/277 [==============================] - 15s 54ms/step - loss: 0.1404 - accuracy: 0.9642 - val_loss: 0.6969 - val_accuracy: 0.8339
# Epoch 6/10
# 277/277 [==============================] - 15s 54ms/step - loss: 0.1042 - accuracy: 0.9727 - val_loss: 0.6553 - val_accuracy: 0.8614
# Epoch 7/10
# 277/277 [==============================] - 15s 56ms/step - loss: 0.0671 - accuracy: 0.9830 - val_loss: 0.6247 - val_accuracy: 0.8671
# Epoch 8/10
# 277/277 [==============================] - 15s 54ms/step - loss: 0.0497 - accuracy: 0.9857 - val_loss: 0.6505 - val_accuracy: 0.8628
# Epoch 9/10
# 277/277 [==============================] - 15s 54ms/step - loss: 0.0401 - accuracy: 0.9861 - val_loss: 0.6639 - val_accuracy: 0.8686
# Epoch 10/10
# 277/277 [==============================] - 15s 53ms/step - loss: 0.0462 - accuracy: 0.9848 - val_loss: 0.7105 - val_accuracy: 0.8592
# 25/25 [==============================] - 1s 24ms/step - loss: 0.5532 - accuracy: 0.8792
# Test Loss: 0.5532233119010925
# Test Accuracy: 0.8792207837104797

# %%
df2 = pd.read_csv("D:/public_dat/test.csv")
df2['Sentence'] = df2['Sentence'].str.lower()

# %%
sentences2=[]
for jok in df2['Sentence']:
    sentences2.append(jok)
word12=[]
for jok in df2['Entity_1']:
    word12.append(jok)
word22=[]
for jok in df2['Entity_2']:
    word22.append(jok)
    
# Separate data into input (sentences) and output (relations)
#sentences = np.array(sentences)
#word1 = np.array([df['Entity_1']])
#word2 = np.array([df['Entity_2']])
#relations = np.array([df['Relation']])
#sentences=sentences.flatten()
#word1=word1.flatten()
#word2=word2.flatten()
#relations=relations.flatten()
#print(relations)
# Tokenize sentences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences + word1 + word2)
vocab_size = len(tokenizer.word_index) + 1

# Encode sentences and relations
X_sentences2 = tokenizer.texts_to_sequences(sentences2)
X_word12 = tokenizer.texts_to_sequences(word12)
X_word22 = tokenizer.texts_to_sequences(word22)
max_len = 256
X_sentences2 = pad_sequences(X_sentences2, maxlen=max_len)
X_word12 = pad_sequences(X_word12, maxlen=1)
X_word22 = pad_sequences(X_word22, maxlen=1)

# %%
X_sentences_text2 = tokenizer.sequences_to_texts(X_sentences2)
#print(X_sentences_text2)

# %%
df2['Id']
# Out:
# 0       8920
# 1         64
# 2       2755
# 3       6871
# 4       7305
#         ...
# 1315    8344
# 1316    5943
# 1317    4424
# 1318    4457
# 1319    6012
# Name: Id, Length: 1320, dtype: int64

# %%
pred = model.predict({"input_sentences": X_sentences2})
predicted_labels = np.argmax(pred, axis=1)
predicted_labels_text = label_encoder.inverse_transform(predicted_labels)

# Display test input sentences and corresponding predicted labels

for sentence,senteces1, predicted_label in zip(word12,word22, predicted_labels_text):
  
    print(f"Input word1: {sentence}")
    print(f"Input word2: {senteces1}")
    print(f"Predicted Label: {predicted_label}")
    print()
data={'Id':df2['Id'],'Relation':predicted_labels_text}
dfk=pd.DataFrame(data)
# Out:
# 42/42 [==============================] - 2s 25ms/step
# Input word1: Equipment
# Input word2: Safety
# Predicted Label: affects
#
# Input word1: tax evasion
# Input word2: government revenues
# Predicted Label: affects
#
# Input word1: flat market
# Input word2: FX revenues
# Predicted Label: affects
#
# Input word1: lengthy shutdown
# Input word2: welfare, food stamps and programs
# Predicted Label: affects
#
# Input word1: Property tax
# Input word2: Annual expenses
# Predicted Label: involves
#
# Input word1: product recalls
# Input word2: sales
# Predicted Label: affects
#
# Input word1: lapse in appropriations
# Input word2: Federal Contractors
# Predicted Label: affects
#
# Input word1: Credit card
# Input word2: Credit card companies' profits
# Predicted Label: affects
#
# Input word1: industrial users
# Input word2: Investment Program
# Predicted Label: affects
#
# Input word1: shutdown
# Input word2: civilian workers at the service academies
# Predicted Label: affects
#
# Input word1: cancellation notices
# Input word2: population
# Predicted Label: affects
#
# Input word1: energy business
# Input word2: timing of payments
# Predicted Label: affects
#
# Input word1: partial shutdown
# Input word2: economy
# Predicted Label: affects
#
# Input word1: Nations are also weighing how far the board should be able to make decisions
# Input word2: national bank deposit-guarantee schemes
# Predicted Label: affects
#
# Input word1: Economic Indicators
# Input word2: Investors
# Predicted Label: affects
#
# Input word1: 1:12 initiative
# Input word2: companies and managers
# Predicted Label: affects
#
# Input word1: Affordable Care Act
# Input word2: Small business
# Predicted Label: affects
#
# Input word1: Unilever
# Input word2: other consumer staples stocks
# Predicted Label: affects
#
# Input word1: Fraud
# Input word2: Carrier
# Predicted Label: affects
#
# Input word1: Fraud
# Input word2: customers
# Predicted Label: affects
#
# Input word1: Tax
# Input word2: TaxPayers
# Predicted Label: affects
#
# Input word1: legislation
# Input word2: central bank
# Predicted Label: affects
#
# Input word1: Design
# Input word2: Safety
# Predicted Label: affects
#
# Input word1: Cytomegalovirus
# Input word2: patients
# Predicted Label: affects
#
# Input word1: "Moritz Erhardt's death
# Input word2: everyone
# Predicted Label: affects
#
# Input word1: movement in the Blumont share price
# Input word2: commercial terms of the takeover proposal
# Predicted Label: affects
#
# Input word1: FCPA
# Input word2: how companies deal with many officials
# Predicted Label: affects
#
# Input word1: anxious and feeling insecure economically
# Input word2: performance at work
# Predicted Label: affects
#
# Input word1: Global Events
# Input word2: Currencies
# Predicted Label: affects
#
# Input word1: cyclone
# Input word2: districts
# Predicted Label: affects
#
# Input word1: financial regulations
# Input word2: change to the DC
# Predicted Label: affects
#
# Input word1: lapse in appropriations
# Input word2: contractors
# Predicted Label: affects
#
# Input word1: longer government agencies remain closed
# Input word2: broader industry
# Predicted Label: affects
#
# Input word1: currency fluctuations
# Input word2: results
# Predicted Label: affects
#
# Input word1: food prices rising
# Input word2: nellore
# Predicted Label: affects
#
# Input word1: good-faith bargaining
# Input word2: labor laws
# Predicted Label: affects
#
# Input word1: penalty imposed
# Input word2: short or long term objectives
# Predicted Label: affects
#
# Input word1: shutdown
# Input word2: manufacturing
# Predicted Label: affects
#
# Input word1: market volatility
# Input word2: Rare-earth prices
# Predicted Label: affects
#
# Input word1: halt
# Input word2: Fannie Mae and Freddie Mac
# Predicted Label: affects
#
# Input word1: disease
# Input word2: people
# Predicted Label: affects
#
# Input word1: catastrophes
# Input word2: people
# Predicted Label: affects
#
# Input word1: Program
# Input word2: Arizonans
# Predicted Label: affects
#
# Input word1: fundamental issues
# Input word2: next generation
# Predicted Label: represents
#
# Input word1: revolts
# Input word2: countries
# Predicted Label: affects
#
# Input word1: revelations
# Input word2: U.S. companies
# Predicted Label: affects
#
# Input word1: proposed measure
# Input word2: Keystone
# Predicted Label: affects
#
# Input word1: change
# Input word2: futures markets
# Predicted Label: affects
#
# Input word1: job cuts yesterday
# Input word2: customer service
# Predicted Label: affects
#
# Input word1: Great Depression
# Input word2: generation
# Predicted Label: affects
#
# Input word1: inventory shortages than at other Japanese carriers.
# Input word2: NTT DoCoMo Inc.
# Predicted Label: affects
#
# Input word1: Debate
# Input word2: Financial Markets
# Predicted Label: affects
#
# Input word1: litigation expenses
# Input word2: capital plans
# Predicted Label: affects
#
# Input word1: ancient practices
# Input word2: chronically stressed
# Predicted Label: affects
#
# Input word1: Dassault Systems
# Input word2: delayed basis
# Predicted Label: affects
#
# Input word1: cancellation notices
# Input word2: population
# Predicted Label: affects
#
# Input word1: student loan
# Input word2: affordability of higher education
# Predicted Label: affects
#
# Input word1: storms
# Input word2: airports
# Predicted Label: affects
#
# Input word1: chinese-invested corporates
# Input word2: national security
# Predicted Label: affects
#
# Input word1: target diseases
# Input word2: people worldwide
# Predicted Label: sells
#
# Input word1: FTT
# Input word2: European nations
# Predicted Label: affects
#
# Input word1: higher mortgage rates
# Input word2: sector
# Predicted Label: affects
#
# Input word1: gap
# Input word2: Petrobras
# Predicted Label: affects
#
# Input word1: sequestration
# Input word2: supply chain
# Predicted Label: affects
#
# Input word1: public
# Input word2: democracy
# Predicted Label: offers
#
# Input word1: BioMarin
# Input word2: patients
# Predicted Label: affects
#
# Input word1: trends
# Input word2: industry
# Predicted Label: affects
#
# Input word1: deferred compensation
# Input word2: risk tolerance
# Predicted Label: affects
#
# Input word1: food price inflation
# Input word2: Unilever
# Predicted Label: affects
#
# Input word1: reducing the queues
# Input word2: economic role of exchange market
# Predicted Label: affects
#
# Input word1: political situation
# Input word2: economy
# Predicted Label: affects
#
# Input word1: Honeymoon in vegas
# Input word2: character of Tommy
# Predicted Label: affects
#
# Input word1: food taxes
# Input word2: sugar-sweetened drinks
# Predicted Label: affects
#
# Input word1: Change in Areas
# Input word2: Water Levels
# Predicted Label: affects
#
# Input word1: FCPA
# Input word2: companies
# Predicted Label: affects
#
# Input word1: service level
# Input word2: production at some facilities
# Predicted Label: involves
#
# Input word1: crisis
# Input word2: jobs
# Predicted Label: affects
#
# Input word1: trend
# Input word2: big banks
# Predicted Label: affects
#
# Input word1: The shift
# Input word2: Danske's market share
# Predicted Label: affects
#
# Input word1: senator
# Input word2: policy
# Predicted Label: affects
#
# Input word1: competition in the car market
# Input word2: revenue
# Predicted Label: affects
#
# Input word1: difficult market conditions
# Input word2: quarter
# Predicted Label: affects
#
# Input word1: Stock market
# Input word2: Investor sentiment
# Predicted Label: affects
#
# Input word1: Any type of disruption in government operations would adversely affect government spending
# Input word2: government spending
# Predicted Label: affects
#
# Input word1: promotional activities
# Input word2: growth
# Predicted Label: affects
#
# Input word1: contaminated whey-protein ingredient.
# Input word2: items
# Predicted Label: affects
#
# Input word1: areas
# Input word2: GDP
# Predicted Label: affects
#
# Input word1: commonwealth's fiscal stability
# Input word2: municipal markets
# Predicted Label: affects
#
# Input word1: debt consolidation
# Input word2: overall debt
# Predicted Label: affects
#
# Input word1: blaze
# Input word2: refinery's ability
# Predicted Label: affects
#
# Input word1: Storm
# Input word2: Refinery
# Predicted Label: affects
#
# Input word1: Movements
# Input word2: Values
# Predicted Label: affects
#
# Input word1: Credit card
# Input word2: Financial well-being
# Predicted Label: affects
#
# Input word1: Government monetary policies
# Input word2: Stock market stability
# Predicted Label: affects
#
# Input word1: dividend policies
# Input word2: income investors
# Predicted Label: affects
#
# Input word1: Risk Appetite Affects
# Input word2: Strategies
# Predicted Label: affects
#
# Input word1: change
# Input word2: deference
# Predicted Label: affects
#
# Input word1: flooding
# Input word2: 10,000 factories
# Predicted Label: affects
#
# Input word1: settlement
# Input word2: daily departures
# Predicted Label: affects
#
# Input word1: correction of its report to the FSA or by business improvement
# Input word2: Credit rating
# Predicted Label: affects
#
# Input word1: market sentiment
# Input word2: ipo success
# Predicted Label: determines
#
# Input word1: drought
# Input word2: harvest
# Predicted Label: invests
#
# Input word1: Ford-fueled social media buzz
# Input word2: sales
# Predicted Label: affects
#
# Input word1: stock buybacks
# Input word2: Shareholders equity
# Predicted Label: impacts
#
# Input word1: drags
# Input word2: U.S. economy
# Predicted Label: affects
#
# Input word1: drought
# Input word2: harvest
# Predicted Label: affects
#
# Input word1: Federal Lawsuit Allen Grunes didn't think Abbott's decision to settle
# Input word2: the federal lawsuit.
# Predicted Label: affects
#
# Input word1: flawed debut
# Input word2: insurer
# Predicted Label: affects
#
# Input word1: tax bill
# Input word2: industries and markets
# Predicted Label: affects
#
# Input word1:  the outcome
# Input word2: Fannie Mae and Freddie Mac
# Predicted Label: affects
#
# Input word1: a $2,199 3-D printer
# Input word2: computer programed
# Predicted Label: creates
#
# Input word1: agreement
# Input word2: a joint venture with Qatar's QInvest LLC
# Predicted Label: creates
#
# Input word1: Financial advisor
# Input word2: Retirement plan
# Predicted Label: creates
#
# Input word1: Patient Protection and Affordable Care Act
# Input word2: public marketplaces, called exchanges
# Predicted Label: creates
#
# Input word1: More national view
# Input word2: pressure
# Predicted Label: creates
#
# Input word1: Mutual fund
# Input word2: Investment
# Predicted Label: creates
#
# Input word1: Democratic dominance
# Input word2: significant disadvantage
# Predicted Label: creates
#
# Input word1: appointment
# Input word2: expectations
# Predicted Label: creates
#
# Input word1: OSX
# Input word2: the Embraer of the seas
# Predicted Label: offers
#
# Input word1: Dia Art Foundation
# Input word2: acquisition fund
# Predicted Label: creates
#
# Input word1: lender
# Input word2: bank
# Predicted Label: creates
#
# Input word1: Patient Protection and Affordable Care Act of 2010
# Input word2: marketplace
# Predicted Label: creates
#
# Input word1: Innovations
# Input word2: Cures
# Predicted Label: creates
#
# Input word1: Kortz
# Input word2: Porter Robotics Institute
# Predicted Label: creates
#
# Input word1: Bank
# Input word2: Credit card
# Predicted Label: creates
#
# Input word1: Positive data
# Input word2: momentum effect
# Predicted Label: creates
#
# Input word1: UN
# Input word2: commission
# Predicted Label: creates
#
# Input word1: Escalatory action
# Input word2: Risks of an incident
# Predicted Label: creates
#
# Input word1: great bottle
# Input word2: itself.
# Predicted Label: creates
#
# Input word1: stop spending
# Input word2: chain reaction
# Predicted Label: creates
#
# Input word1: baseball stadium
# Input word2: jobs
# Predicted Label: creates
#
# Input word1: Insurance money
# Input word2: frenzy of repair
# Predicted Label: creates
#
# Input word1: Bank
# Input word2: Savings account
# Predicted Label: creates
#
# Input word1: groups
# Input word2: Instability
# Predicted Label: creates
#
# Input word1: Health Coverage
# Input word2: pool
# Predicted Label: creates
#
# Input word1: rollover
# Input word2: account
# Predicted Label: creates
#
# Input word1: easy money
# Input word2: bubbles in assets
# Predicted Label: creates
#
# Input word1: uncertainty
# Input word2: home
# Predicted Label: creates
#
# Input word1: Startup business
# Input word2: Jobs
# Predicted Label: invests
#
# Input word1: Dudley
# Input word2: mechanisms
# Predicted Label: creates
#
# Input word1: clinics
# Input word2: largest chain of private hospitals.
# Predicted Label: creates
#
# Input word1: Commodity
# Input word2: Prices
# Predicted Label: creates
#
# Input word1: Disability insurance
# Input word2: Peace of mind
# Predicted Label: creates
#
# Input word1: Adair Turner
# Input word2: Financial Services Authority
# Predicted Label: creates
#
# Input word1: famed hotel
# Input word2: 1954 Dining Experienc
# Predicted Label: creates
#
# Input word1: Cuomo
# Input word2: commission
# Predicted Label: creates
#
# Input word1: This
# Input word2: condominium
# Predicted Label: creates
#
# Input word1: The Federal Reserve
# Input word2: Janet Yellen
# Predicted Label: creates
#
# Input word1: Mining
# Input word2: jobs
# Predicted Label: creates
#
# Input word1: Canada
# Input word2: 11,000 jobs
# Predicted Label: creates
#
# Input word1: Fortress Investment Group LLC
# Input word2: Lewisville
# Predicted Label: invests
#
# Input word1: AB Bermuda
# Input word2: MB Bermuda
# Predicted Label: creates
#
# Input word1: Bosco
# Input word2: stores
# Predicted Label: creates
#
# Input word1: Rest of the UK
# Input word2: such a system
# Predicted Label: creates
#
# Input word1: Merger
# Input word2: TUI travels
# Predicted Label: creates
#
# Input word1: Money market account
# Input word2: Investment
# Predicted Label: creates
#
# Input word1: criminal
# Input word2: fake tax returns
# Predicted Label: creates
#
# Input word1: foreign companies
# Input word2: jobs
# Predicted Label: creates
#
# Input word1: disparity
# Input word2: unintended effects,
# Predicted Label: creates
#
# Input word1: Saudi Arabia
# Input word2: jobs
# Predicted Label: creates
#
# Input word1: hardis
# Input word2: Giving Pledge
# Predicted Label: creates
#
# Input word1: funds
# Input word2: jobs
# Predicted Label: affects
#
# Input word1: Sato
# Input word2: Reputation
# Predicted Label: creates
#
# Input word1: You
# Input word2: destiny
# Predicted Label: creates
#
# Input word1: BlackRock
# Input word2: own network
# Predicted Label: manages
#
# Input word1: funds
# Input word2: reserves
# Predicted Label: creates
#
# Input word1: auction
# Input word2: investment
# Predicted Label: offers
#
# Input word1: traders
# Input word2: end-of-day price assessments
# Predicted Label: creates
#
# Input word1: Karl
# Input word2: S&P/Case-Shiller home price indexes
# Predicted Label: creates
#
# Input word1: News Corp
# Input word2: 21st Century Fox
# Predicted Label: creates
#
# Input word1: he
# Input word2: creates jobs
# Predicted Label: creates
#
# Input word1: government
# Input word2: create jobs
# Predicted Label: creates
#
# Input word1: markets
# Input word2: fourth vacancy
# Predicted Label: creates
#
# Input word1: Iran
# Input word2: nuclear weapon.
# Predicted Label: creates
#
# Input word1: Bank
# Input word2: Savings account
# Predicted Label: creates
#
# Input word1: policy deviations
# Input word2: boom-bust cycle
# Predicted Label: creates
#
# Input word1: i
# Input word2: a large open space the homeowners wanted
# Predicted Label: creates
#
# Input word1: Skype Inc
# Input word2: the venture capital
# Predicted Label: creates
#
# Input word1: labor market's ongoing struggles
# Input word2: office-using job
# Predicted Label: creates
#
# Input word1: Mutual fund
# Input word2: Investment
# Predicted Label: creates
#
# Input word1: cryptographic challenges
# Input word2: digital money
# Predicted Label: creates
#
# Input word1: FICO
# Input word2: long-term loyalty.
# Predicted Label: creates
#
# Input word1: enterprises,
# Input word2: federal government
# Predicted Label: creates
#
# Input word1: John Hayase
# Input word2: Smith of Smule
# Predicted Label: creates
#
# Input word1: company
# Input word2: sensor module
# Predicted Label: creates
#
# Input word1: IM2.0
# Input word2: online strategies and ad campaigns.
# Predicted Label: creates
#
# Input word1: to make them look real
# Input word2: The ex-employees "obsessed" over the details of fake documents
# Predicted Label: creates
#
# Input word1: 14 States, washington, DC
# Input word2: online exchanges
# Predicted Label: creates
#
# Input word1: Securities Investor Protection Corp
# Input word2: Congress
# Predicted Label: creates
#
# Input word1: retailer
# Input word2: social network for the company's Shop
# Predicted Label: generates
#
# Input word1: Rousseff
# Input word2: body
# Predicted Label: creates
#
# Input word1: White House
# Input word2: concern
# Predicted Label: impacts
#
# Input word1: pro-growth policies
# Input word2: create jobs
# Predicted Label: creates
#
# Input word1: Nor Lipez co-op
# Input word2: opportunities
# Predicted Label: creates
#
# Input word1: promote competition
# Input word2: stronger carrier
# Predicted Label: creates
#
# Input word1: ministry
# Input word2: land banks
# Predicted Label: creates
#
# Input word1: solar technology
# Input word2: new possibility
# Predicted Label: creates
#
# Input word1: Value Chain
# Input word2: a conflict with the other U.S. carriers,
# Predicted Label: creates
#
# Input word1: Rollover IRA
# Input word2: Retirement
# Predicted Label: creates
#
# Input word1: Derivative
# Input word2: Hedge
# Predicted Label: creates
#
# Input word1: company
# Input word2: VIX
# Predicted Label: creates
#
# Input word1: Philadelphia
# Input word2: distrit
# Predicted Label: creates
#
# Input word1: deal
# Input word2: formidable competitor
# Predicted Label: creates
#
# Input word1: LME
# Input word2: market
# Predicted Label: creates
#
# Input word1: famed hotel
# Input word2: 1954 Dining Experienc
# Predicted Label: creates
#
# Input word1: Duke
# Input word2: culture
# Predicted Label: creates
#
# Input word1: America Invents Act
# Input word2: partes review
# Predicted Label: creates
#
# Input word1: Bonventre work
# Input word2: template for fake statements from Depository Trust Co.
# Predicted Label: creates
#
# Input word1: engaged community
# Input word2: barrier
# Predicted Label: creates
#
# Input word1: John Hayase
# Input word2: Smith of Smule
# Predicted Label: creates
#
# Input word1: Non-bank financial firms
# Input word2: Financial Stability Oversight Council
# Predicted Label: creates
#
# Input word1: Democratic dominance
# Input word2: significant disadvantage
# Predicted Label: creates
#
# Input word1: hydraulics fracturing
# Input word2: surge in gas supplies
# Predicted Label: creates
#
# Input word1: bill
# Input word2: protection bureau
# Predicted Label: creates
#
# Input word1: maturity mismatch
# Input word2: refinancing risks
# Predicted Label: invests
#
# Input word1: retailers
# Input word2: shopping apps
# Predicted Label: creates
#
# Input word1: Anhui Sun
# Input word2: electronics
# Predicted Label: creates
#
# Input word1: Arizona
# Input word2: 2,000 jobs.
# Predicted Label: creates
#
# Input word1: Credit card
# Input word2: APR
# Predicted Label: creates
#
# Input word1: Bank
# Input word2: Investment
# Predicted Label: creates
#
# Input word1: reserve
# Input word2: severity
# Predicted Label: determines
#
# Input word1: Effects
# Input word2: Government shutdown
# Predicted Label: determines
#
# Input word1: schools
# Input word2: code of conduct
# Predicted Label: determines
#
# Input word1: yield garde
# Input word2: grade quality
# Predicted Label: determines
#
# Input word1: central bank
# Input word2: swaps activity
# Predicted Label: determines
#
# Input word1: Grade
# Input word2: quality
# Predicted Label: determines
#
# Input word1: nations
# Input word2: global warming.
# Predicted Label: determines
#
# Input word1: IRS
# Input word2: conservation purpose
# Predicted Label: determines
#
# Input word1: purchase conditions
# Input word2: oil market
# Predicted Label: determines
#
# Input word1: grade scale
# Input word2: Grade quality
# Predicted Label: determines
#
# Input word1: Valuations
# Input word2: six months
# Predicted Label: determines
#
# Input word1: takeout price
# Input word2: Aeropostale's performance
# Predicted Label: determines
#
# Input word1: court
# Input word2: authenticity of the copyright assignments
# Predicted Label: determines
#
# Input word1: price
# Input word2: currencies
# Predicted Label: determines
#
# Input word1: Analysts
# Input word2: non-federal workers filed
# Predicted Label: determines
#
# Input word1: cut to 0.75 percent
# Input word2: conditions for monetary policy
# Predicted Label: impacts
#
# Input word1: banks
# Input word2: quotes
# Predicted Label: determines
#
# Input word1: sellers
# Input word2: pricing
# Predicted Label: determines
#
# Input word1: European Commission
# Input word2: Expiration
# Predicted Label: determines
#
# Input word1: rates
# Input word2: funds
# Predicted Label: determines
#
# Input word1: party's share of the party vote
# Input word2: makeup of the 120-seat parliament
# Predicted Label: determines
#
# Input word1: USDA
# Input word2: Prices
# Predicted Label: determines
#
# Input word1: major challenge, and successes or failures
# Input word2: Kerry's legacy as his nation's top diplomat
# Predicted Label: determines
#
# Input word1: access to patient-level data
# Input word2: if treatment was appropriate
# Predicted Label: determines
#
# Input word1: USDA survey of grain purchasers
# Input word2: prices
# Predicted Label: determines
#
# Input word1: data
# Input word2: dosing
# Predicted Label: affects
#
# Input word1: trial
# Input word2: patent
# Predicted Label: determines
#
# Input word1: process
# Input word2: information
# Predicted Label: determines
#
# Input word1: power
# Input word2: mayor
# Predicted Label: determines
#
# Input word1: varying levels of seniority in the holdings
# Input word2: creditors are paid first,
# Predicted Label: determines
#
# Input word1: USDA survey
# Input word2: prices
# Predicted Label: determines
#
# Input word1: AlphaMetrix
# Input word2: funds
# Predicted Label: determines
#
# Input word1: Commission
# Input word2: Investigation
# Predicted Label: determines
#
# Input word1: a USDA survey of grain purchasers
# Input word2: Prices
# Predicted Label: determines
#
# Input word1: Grade quality
# Input word2: 1-5 yield grade scale
# Predicted Label: determines
#
# Input word1: power
# Input word2: mayor
# Predicted Label: determines
#
# Input word1: Oklahoma State (9-1) rounds
# Input word2: Harris Interactive Poll,
# Predicted Label: determines
#
# Input word1: market
# Input word2: exchange rate
# Predicted Label: determines
#
# Input word1: Iran
# Input word2: to continue uranium enrichment
# Predicted Label: determines
#
# Input word1: Sonangol
# Input word2: way
# Predicted Label: determines
#
# Input word1: incident
# Input word2: vehicle safety implications
# Predicted Label: determines
#
# Input word1: Supermajority
# Input word2: Rules
# Predicted Label: determines
#
# Input word1: discussions
# Input word2: dialogue
# Predicted Label: determines
#
# Input word1: Holder and his team
# Input word2: biggest fraud cases of financial crisis
# Predicted Label: determines
#
# Input word1: surveys
# Input word2: pricing
# Predicted Label: determines
#
# Input word1: trust
# Input word2: sell holding to fiat
# Predicted Label: determines
#
# Input word1: valuations
# Input word2: margin calls
# Predicted Label: determines
#
# Input word1: careful study
# Input word2: EPS guidance
# Predicted Label: determines
#
# Input word1: cuts in dollars a hundredweight
# Input word2: prices
# Predicted Label: determines
#
# Input word1: wages
# Input word2: fate of abenomics
# Predicted Label: determines
#
# Input word1: FDA staff members
# Input word2: patients
# Predicted Label: determines
#
# Input word1: USDA survey of grain purchasers
# Input word2: prices
# Predicted Label: determines
#
# Input word1: Treasury Secretary
# Input word2: supervised
# Predicted Label: determines
#
# Input word1: Government
# Input word2: Behind
# Predicted Label: determines
#
# Input word1: APR feeds into calculations
# Input word2: a mortgage is a higher-priced loan.
# Predicted Label: determines
#
# Input word1: Justice Brer...
# Input word2: trial
# Predicted Label: determines
#
# Input word1: infringement
# Input word2: willfulness
# Predicted Label: determines
#
# Input word1: gaokao
# Input word2: fates of millions of young people
# Predicted Label: determines
#
# Input word1: software
# Input word2: personality and cognitive abilities
# Predicted Label: determines
#
# Input word1: Nunn
# Input word2: opponent
# Predicted Label: determines
#
# Input word1: quality of life
# Input word2: living
# Predicted Label: determines
#
# Input word1: Novartis
# Input word2: former workers
# Predicted Label: determines
#
# Input word1: 124,000 people
# Input word2: eligibility to purchase insurance
# Predicted Label: determines
#
# Input word1: Splintered Republicans The fiscal confrontation
# Input word2: leverage their party's House majority
# Predicted Label: determines
#
# Input word1: Pegasus
# Input word2: risk
# Predicted Label: determines
#
# Input word1: Licenses
# Input word2: Casinos
# Predicted Label: determines
#
# Input word1: Obama authority
# Input word2: plans
# Predicted Label: determines
#
# Input word1: physical therapy
# Input word2: able to compete
# Predicted Label: determines
#
# Input word1: Giorgio Napolitano
# Input word2: snap vote
# Predicted Label: determines
#
# Input word1: Grade quality
# Input word2: 1-5 yield grade scale.
# Predicted Label: determines
#
# Input word1: Saudi Arabian border guards
# Input word2: the source of the attack
# Predicted Label: determines
#
# Input word1: cuts in dollars a hundredweight
# Input word2: prices
# Predicted Label: determines
#
# Input word1: Fed
# Input word2: markets
# Predicted Label: determines
#
# Input word1: independents
# Input word2: Republicans
# Predicted Label: represents
#
# Input word1: victory
# Input word2: Afghanistan
# Predicted Label: determines
#
# Input word1: White House...
# Input word2: agencies
# Predicted Label: determines
#
# Input word1: USDA
# Input word2: Prices
# Predicted Label: determines
#
# Input word1: Iran's declared nuclear facilities,
# Input word2: hidden nuclear-weapons
# Predicted Label: determines
#
# Input word1: the pool of people who apply for insurance
# Input word2: its price and quality
# Predicted Label: determines
#
# Input word1: Leaders of both parties
# Input word2: Tea Partiers
# Predicted Label: determines
#
# Input word1: hearing
# Input word2: breakdowns
# Predicted Label: represents
#
# Input word1: shareholders
# Input word2: chief-executive compensation
# Predicted Label: determines
#
# Input word1: Washington state
# Input word2: eligibility for insurance
# Predicted Label: determines
#
# Input word1: Charles Moffett
# Input word2: bidders
# Predicted Label: determines
#
# Input word1: board of directors
# Input word2: governance requirements
# Predicted Label: determines
#
# Input word1: European Commission
# Input word2: Expiration
# Predicted Label: determines
#
# Input word1: governors
# Input word2: health-care law
# Predicted Label: determines
#
# Input word1: IPCC
# Input word2: Disciplinary action
# Predicted Label: determines
#
# Input word1: cuts in dollars
# Input word2: Prices
# Predicted Label: determines
#
# Input word1: cuts
# Input word2: prices
# Predicted Label: determines
#
# Input word1: cuts in dollars a hundredweight
# Input word2: prices
# Predicted Label: determines
#
# Input word1: America Movil
# Input word2: Decision
# Predicted Label: determines
#
# Input word1: NWR
# Input word2: Paskov
# Predicted Label: determines
#
# Input word1: bracelet
# Input word2: location
# Predicted Label: determines
#
# Input word1: company
# Input word2: long term goals
# Predicted Label: determines
#
# Input word1: Effects
# Input word2: Government shutdown
# Predicted Label: determines
#
# Input word1: Firms
# Input word2: true profit
# Predicted Label: generates
#
# Input word1: effect of race cancel
# Input word2: economy
# Predicted Label: offers
#
# Input word1: countries
# Input word2: commitments
# Predicted Label: determines
#
# Input word1: yeild grade
# Input word2: grade quality
# Predicted Label: determines
#
# Input word1: the right to review EU investments
# Input word2: they are of 'net benefit"
# Predicted Label: determines
#
# Input word1: 1-5 yield grade scale
# Input word2: grade quality
# Predicted Label: determines
#
# Input word1: cuts in dollars
# Input word2: Prices
# Predicted Label: determines
#
# Input word1: setup,process flows
# Input word2: feasibility
# Predicted Label: determines
#
# Input word1: Obama and allies
# Input word2: way
# Predicted Label: determines
#
# Input word1: lender
# Input word2: margin
# Predicted Label: determines
#
# Input word1: country's retail price index
# Input word2: rate of inflation
# Predicted Label: determines
#
# Input word1: footnote
# Input word2: U.S. related product
# Predicted Label: determines
#
# Input word1: Jurors
# Input word2: age
# Predicted Label: determines
#
# Input word1: USDA
# Input word2: Prices
# Predicted Label: determines
#
# Input word1: job gains
# Input word2: land rush
# Predicted Label: generates
#
# Input word1: Facebook
# Input word2: revenue
# Predicted Label: generates
#
# Input word1: TTPP
# Input word2: power
# Predicted Label: generates
#
# Input word1: fund working capital
# Input word2: cash
# Predicted Label: generates
#
# Input word1: Big Spenders
# Input word2: fees
# Predicted Label: generates
#
# Input word1: Marijuana legalization
# Input word2: tax revenue
# Predicted Label: generates
#
# Input word1: Sen-Sen and Fox's mints
# Input word2: sales
# Predicted Label: generates
#
# Input word1: merger
# Input word2: revenue
# Predicted Label: generates
#
# Input word1: Visa
# Input word2: Revenue
# Predicted Label: generates
#
# Input word1: contrary
# Input word2: conditions
# Predicted Label: generates
#
# Input word1: souped-up cars
# Input word2: buzz
# Predicted Label: generates
#
# Input word1: retailer
# Input word2: revenue
# Predicted Label: generates
#
# Input word1: Dexus
# Input word2: rents
# Predicted Label: offers
#
# Input word1: emission-reduction projects
# Input word2: offsets against pollution
# Predicted Label: generates
#
# Input word1: plant
# Input word2: power
# Predicted Label: generates
#
# Input word1: the company
# Input word2: revenue
# Predicted Label: invests
#
# Input word1: funds
# Input word2: fees
# Predicted Label: generates
#
# Input word1: JPMorgan
# Input word2: $1.5 billion in fees
# Predicted Label: generates
#
# Input word1: mobile devices
# Input word2: Twitter's ad revenue
# Predicted Label: generates
#
# Input word1: some
# Input word2: profits
# Predicted Label: generates
#
# Input word1: Hinkley Point
# Input word2: megawatts
# Predicted Label: generates
#
# Input word1: business
# Input word2: profit
# Predicted Label: generates
#
# Input word1: Serco
# Input word2: revenue
# Predicted Label: generates
#
# Input word1: The U.S. government
# Input word2: 8 percent of EMC's revenue
# Predicted Label: generates
#
# Input word1: Dreamliner, a jet
# Input word2: ero or worse margins
# Predicted Label: generates
#
# Input word1: projects
# Input word2: returns
# Predicted Label: generates
#
# Input word1: corporate documents
# Input word2: amount
# Predicted Label: generates
#
# Input word1: JPMorgan
# Input word2: revenue
# Predicted Label: generates
#
# Input word1: resources
# Input word2: returns
# Predicted Label: generates
#
# Input word1: Facebook
# Input word2: Ad Revenue
# Predicted Label: generates
#
# Input word1: excessive levels of debt
# Input word2: lot of risk
# Predicted Label: generates
#
# Input word1: Damac
# Input word2: profit
# Predicted Label: generates
#
# Input word1: Morgan Stanley
# Input word2: revenue
# Predicted Label: generates
#
# Input word1: patented
# Input word2: ad revenue
# Predicted Label: generates
#
# Input word1: program
# Input word2: losses
# Predicted Label: generates
#
# Input word1: Emlak Konut
# Input word2: revenue
# Predicted Label: generates
#
# Input word1: plant
# Input word2: power
# Predicted Label: generates
#
# Input word1: Emlak Konut
# Input word2: revenue
# Predicted Label: generates
#
# Input word1: Wynn Macau
# Input word2: compounded annual growth rate
# Predicted Label: generates
#
# Input word1: towers
# Input word2: revenue
# Predicted Label: generates
#
# Input word1: China
# Input word2: Revenue
# Predicted Label: generates
#
# Input word1: Twitter
# Input word2: Revenue
# Predicted Label: involves
#
# Input word1: The plants in Himachal Pradesh in Northern India
# Input word2: a combined 1,300 megawatts of power
# Predicted Label: generates
#
# Input word1: Pfizer
# Input word2: $1 billion in sales
# Predicted Label: generates
#
# Input word1: Demand
# Input word2: revenue
# Predicted Label: generates
#
# Input word1: country's expanding economy
# Input word2: wealth
# Predicted Label: generates
#
# Input word1: Redesigned Website The airline
# Input word2: $3.5 billion
# Predicted Label: generates
#
# Input word1: Server
# Input word2: processing power the retailer sells to heavy corporate data users on the cheap,
# Predicted Label: generates
#
# Input word1: change
# Input word2: 724 billion
# Predicted Label: generates
#
# Input word1: Yervoy, another immune system-based drug
# Input word2: $238 million
# Predicted Label: generates
#
# Input word1: company
# Input word2: profit
# Predicted Label: generates
#
# Input word1: New gaming console introductions
# Input word2: sales at low profitability,
# Predicted Label: generates
#
# Input word1: royalties and dividends
# Input word2: cash flow
# Predicted Label: generates
#
# Input word1: analysts projected the drug
# Input word2: $4.3 billion in sales by 2020
# Predicted Label: generates
#
# Input word1: plant
# Input word2: electricity
# Predicted Label: generates
#
# Input word1: substantial efforts
# Input word2: sustainable economic growth
# Predicted Label: generates
#
# Input word1: rooftop solar panels
# Input word2: power and batteries
# Predicted Label: generates
#
# Input word1: ichimoku strategy
# Input word2: return
# Predicted Label: generates
#
# Input word1: Shareholders
# Input word2: returns
# Predicted Label: generates
#
# Input word1: Volvo outlined plans to eliminate 2,000 administrative jobs
# Input word2: annual cost savings
# Predicted Label: generates
#
# Input word1: process
# Input word2: anxieties
# Predicted Label: generates
#
# Input word1: improvement
# Input word2: saving of around $200,000
# Predicted Label: generates
#
# Input word1: group was set up by Barnier
# Input word2: ideas for possible EU legislation
# Predicted Label: generates
#
# Input word1: company
# Input word2: revenue
# Predicted Label: generates
#
# Input word1: Pentagon
# Input word2: energy
# Predicted Label: generates
#
# Input word1: mortgages
# Input word2: exposure to the government
# Predicted Label: generates
#
# Input word1: sunlight
# Input word2: power
# Predicted Label: generates
#
# Input word1: China and India
# Input word2: war
# Predicted Label: generates
#
# Input word1: Copaxone, an injection to treat multiple sclerosis
# Input word2: 20 percent of Teva's $20 billion in revenue last year.
# Predicted Label: generates
#
# Input word1: libra
# Input word2: reais
# Predicted Label: generates
#
# Input word1: PS4
# Input word2: profits
# Predicted Label: generates
#
# Input word1: Visa
# Input word2: Revenue
# Predicted Label: generates
#
# Input word1: business
# Input word2: billions of dollars
# Predicted Label: generates
#
# Input word1: shopping centers
# Input word2: 3.2 billion dirhams
# Predicted Label: generates
#
# Input word1: fast-food chain
# Input word2: sales
# Predicted Label: generates
#
# Input word1: Hinkley Point
# Input word2: megawatts
# Predicted Label: generates
#
# Input word1: company
# Input word2: cash
# Predicted Label: generates
#
# Input word1: Japan is trying to
# Input word2: inflation
# Predicted Label: generates
#
# Input word1: JPMorgan
# Input word2: revenue
# Predicted Label: generates
#
# Input word1: drug
# Input word2: sales
# Predicted Label: generates
#
# Input word1: Sibanye
# Input word2: Cash
# Predicted Label: generates
#
# Input word1: funds
# Input word2: fees
# Predicted Label: generates
#
# Input word1: Apollo Global Management LLC's Athene Holding Ltd.
# Input word2: $2.6 billion
# Predicted Label: generates
#
# Input word1: transaction
# Input word2: gain
# Predicted Label: generates
#
# Input word1: company
# Input word2: value for our shareholders
# Predicted Label: generates
#
# Input word1: isotopes
# Input word2: atomic power
# Predicted Label: generates
#
# Input word1: companies
# Input word2: profits
# Predicted Label: generates
#
# Input word1: reinvested earnings
# Input word2: additional profit
# Predicted Label: generates
#
# Input word1: Defense companie
# Input word2: large portion of sales from the Pentagon
# Predicted Label: generates
#
# Input word1: profitable luxury brands
# Input word2: sufficient trading profit to cover the current level of financial expense
# Predicted Label: generates
#
# Input word1: Deutsche Telekom
# Input word2: cash
# Predicted Label: invests
#
# Input word1: Fund
# Input word2: money
# Predicted Label: generates
#
# Input word1: CR-Z coupe and a version of the Civic
# Input word2: fraction of Prius deliveries
# Predicted Label: generates
#
# Input word1: the media
# Input word2: panic in the population ahead of the elections
# Predicted Label: represents
#
# Input word1: Chiway
# Input word2: 80 percent to 90 percent of its revenue in China
# Predicted Label: generates
#
# Input word1: Singapore
# Input word2: 46.9 terawatt hours last year.
# Predicted Label: generates
#
# Input word1: initiative is in its early stages and the Times
# Input word2: enough content to make it attractive to advertisers
# Predicted Label: generates
#
# Input word1: The cuts
# Input word2: benefits
# Predicted Label: generates
#
# Input word1: accumulation of household debt
# Input word2: key vulnerabilities
# Predicted Label: sells
#
# Input word1: Lemtrada
# Input word2: sales
# Predicted Label: generates
#
# Input word1: The paper
# Input word2: $1.3 billion.
# Predicted Label: generates
#
# Input word1: skeptical
# Input word2: spending
# Predicted Label: represents
#
# Input word1: inherent power of the dollar
# Input word2: guaranteed interest rate returns
# Predicted Label: generates
#
# Input word1: wealth gap
# Input word2: revenue
# Predicted Label: generates
#
# Input word1: coal
# Input word2: power
# Predicted Label: generates
#
# Input word1: Germany-based Bayer
# Input word2: sales
# Predicted Label: generates
#
# Input word1: Electronic Arts
# Input word2: bulk of its revenue from digital downloads within the next five years.
# Predicted Label: generates
#
# Input word1: Tax Shelters
# Input word2: $1 billion
# Predicted Label: generates
#
# Input word1: Coal
# Input word2: energy
# Predicted Label: generates
#
# Input word1: Crown
# Input word2: Sales
# Predicted Label: generates
#
# Input word1: water-related issues
# Input word2: businesses
# Predicted Label: impacts
#
# Input word1: AstraZeneca
# Input word2: generic competition
# Predicted Label: impacts
#
# Input word1: high capex and wages
# Input word2: value-added-tax
# Predicted Label: impacts
#
# Input word1: consumer sentiment
# Input word2: businesses of all nature
# Predicted Label: affects
#
# Input word1: mortgages relief measures
# Input word2: loan-loss provisions
# Predicted Label: impacts
#
# Input word1: shutdown
# Input word2: Payrolls
# Predicted Label: impacts
#
# Input word1: agricultural
# Input word2: revenue
# Predicted Label: impacts
#
# Input word1: earnings
# Input word2: banks
# Predicted Label: impacts
#
# Input word1: slower economic activity
# Input word2: consumer confidence
# Predicted Label: affects
#
# Input word1: tapering
# Input word2: countries
# Predicted Label: impacts
#
# Input word1: Production
# Input word2: shutdown
# Predicted Label: impacts
#
# Input word1: Booze-makers
# Input word2: government bulk purchases
# Predicted Label: impacts
#
# Input word1: markets
# Input word2: currency.
# Predicted Label: impacts
#
# Input word1: sales
# Input word2: unlicensed packs
# Predicted Label: impacts
#
# Input word1: currency
# Input word2: markets
# Predicted Label: impacts
#
# Input word1: greenhouse-gas
# Input word2: project
# Predicted Label: impacts
#
# Input word1: sales
# Input word2: market
# Predicted Label: impacts
#
# Input word1: stadium
# Input word2: neighborhoods
# Predicted Label: impacts
#
# Input word1: fracking
# Input word2: public health
# Predicted Label: impacts
#
# Input word1: pressure on prices
# Input word2: trending down
# Predicted Label: impacts
#
# Input word1: Discretionary spending
# Input word2: consumer confidence
# Predicted Label: impacts
#
# Input word1: sanctions
# Input word2: Iran's economy
# Predicted Label: impacts
#
# Input word1: cohesion
# Input word2: abroad
# Predicted Label: impacts
#
# Input word1: RBA
# Input word2: market
# Predicted Label: impacts
#
# Input word1: slowdown
# Input word2: performance
# Predicted Label: impacts
#
# Input word1: climate change
# Input word2: UN's Adaptation fund
# Predicted Label: impacts
#
# Input word1: European Union regulation
# Input word2: environment
# Predicted Label: impacts
#
# Input word1: currency
# Input word2: Food
# Predicted Label: impacts
#
# Input word1: rate cut
# Input word2: euro
# Predicted Label: impacts
#
# Input word1: devastation
# Input word2: devastation
# Predicted Label: impacts
#
# Input word1: Poor's
# Input word2: bank ratings
# Predicted Label: impacts
#
# Input word1: global warming
# Input word2: climate change
# Predicted Label: impacts
#
# Input word1: investors
# Input word2: holdings
# Predicted Label: impacts
#
# Input word1: Congress studying
# Input word2: excess reserves
# Predicted Label: impacts
#
# Input word1: hedges
# Input word2: volatility
# Predicted Label: impacts
#
# Input word1: iran deal
# Input word2: benchmark stock index
# Predicted Label: impacts
#
# Input word1: economy
# Input word2: government shutdown
# Predicted Label: impacts
#
# Input word1: rising rates
# Input word2: bond funds
# Predicted Label: impacts
#
# Input word1: Environment-related issues
# Input word2: share prices
# Predicted Label: impacts
#
# Input word1: botulism scare
# Input word2: business
# Predicted Label: impacts
#
# Input word1: IPO
# Input word2: stage VC
# Predicted Label: impacts
#
# Input word1: currency
# Input word2: markets
# Predicted Label: impacts
#
# Input word1: Direct Investment Pension funds
# Input word2: reinsurance market
# Predicted Label: impacts
#
# Input word1: stocks
# Input word2: psychology
# Predicted Label: impacts
#
# Input word1: front-line employees
# Input word2: friends
# Predicted Label: impacts
#
# Input word1: coal price
# Input word2: company
# Predicted Label: impacts
#
# Input word1: safety review
# Input word2: oil giant clean up
# Predicted Label: invests
#
# Input word1: shekels
# Input word2: foreign exchange
# Predicted Label: impacts
#
# Input word1: Tax Reform
# Input word2: Economy
# Predicted Label: invests
#
# Input word1: conflict
# Input word2: economy
# Predicted Label: impacts
#
# Input word1: Brent
# Input word2: North sea product
# Predicted Label: impacts
#
# Input word1: central-bank
# Input word2: CPI
# Predicted Label: impacts
#
# Input word1: shutdown
# Input word2: air quality
# Predicted Label: impacts
#
# Input word1: shutdown
# Input word2: Payrolls
# Predicted Label: impacts
#
# Input word1: Mizuho's crime-loan scandal
# Input word2: earnings
# Predicted Label: impacts
#
# Input word1: challenging markest
# Input word2: business units
# Predicted Label: impacts
#
# Input word1: tobin
# Input word2: hamada
# Predicted Label: impacts
#
# Input word1: Saudi Arabia
# Input word2: crude production
# Predicted Label: sells
#
# Input word1: unwind of U.S. dollars
# Input word2: risk trades
# Predicted Label: impacts
#
# Input word1: Fed
# Input word2: Speculation
# Predicted Label: impacts
#
# Input word1: tax changes negatively
# Input word2: Company
# Predicted Label: impacts
#
# Input word1: confidence-building measure
# Input word2: equity markets
# Predicted Label: impacts
#
# Input word1: eforts
# Input word2: bonds
# Predicted Label: impacts
#
# Input word1: White House
# Input word2: concern
# Predicted Label: impacts
#
# Input word1: reserve margin
# Input word2: industrial costumers
# Predicted Label: impacts
#
# Input word1: tax
# Input word2: local television
# Predicted Label: impacts
#
# Input word1: Typhoon
# Input word2: growth
# Predicted Label: impacts
#
# Input word1: White House
# Input word2: concern
# Predicted Label: impacts
#
# Input word1: rate reduction
# Input word2: economy
# Predicted Label: impacts
#
# Input word1: Belaruskali
# Input word2: market
# Predicted Label: impacts
#
# Input word1: India-Iran oil deal
# Input word2: oil market
# Predicted Label: invests
#
# Input word1: royalty demand letter
# Input word2: small business
# Predicted Label: impacts
#
# Input word1: Forties Output
# Input word2: shutdown
# Predicted Label: impacts
#
# Input word1: Fed
# Input word2: american economy
# Predicted Label: impacts
#
# Input word1: Growth
# Input word2: measures
# Predicted Label: impacts
#
# Input word1: shutdown
# Input word2: economy
# Predicted Label: impacts
#
# Input word1: higher minimum pay
# Input word2: employment of low-wage workers
# Predicted Label: impacts
#
# Input word1: Other shares
# Input word2: gauge
# Predicted Label: impacts
#
# Input word1: Syrian civil war
# Input word2: country's economy
# Predicted Label: impacts
#
# Input word1: stadium
# Input word2: neighborhoods
# Predicted Label: impacts
#
# Input word1: critical relief operations
# Input word2: Haiyan
# Predicted Label: impacts
#
# Input word1: ECB
# Input word2: French bonds
# Predicted Label: impacts
#
# Input word1: public scandal
# Input word2: marriage
# Predicted Label: impacts
#
# Input word1: safety review
# Input word2: oil giants clean up
# Predicted Label: invests
#
# Input word1: debt deal
# Input word2: emerging markets
# Predicted Label: impacts
#
# Input word1: shutdown
# Input word2: Huawei Technologies Co.
# Predicted Label: impacts
#
# Input word1: campaign
# Input word2: equity
# Predicted Label: impacts
#
# Input word1: Currency
# Input word2: results
# Predicted Label: impacts
#
# Input word1: employees
# Input word2: pattern or practice of discrimination
# Predicted Label: impacts
#
# Input word1: EIB sales
# Input word2: Carbon
# Predicted Label: impacts
#
# Input word1: Air's dual antennas
# Input word2: Speed Boost Users
# Predicted Label: impacts
#
# Input word1: challenges
# Input word2: client activity
# Predicted Label: impacts
#
# Input word1: economic
# Input word2: government
# Predicted Label: impacts
#
# Input word1: touch one hair
# Input word2: body
# Predicted Label: impacts
#
# Input word1: single act
# Input word2: market
# Predicted Label: impacts
#
# Input word1: CPI
# Input word2: central-bank policy
# Predicted Label: impacts
#
# Input word1: Global Environment Facility
# Input word2: finance
# Predicted Label: impacts
#
# Input word1: Saudi Arabia
# Input word2: crude production
# Predicted Label: sells
#
# Input word1: facebook
# Input word2: jim prosser
# Predicted Label: impacts
#
# Input word1: borrowing limit
# Input word2: world
# Predicted Label: impacts
#
# Input word1: alignment
# Input word2: costs
# Predicted Label: impacts
#
# Input word1: Global Environment Facility
# Input word2: finance
# Predicted Label: impacts
#
# Input word1: loss
# Input word2: climate
# Predicted Label: impacts
#
# Input word1: market
# Input word2: website woes
# Predicted Label: invests
#
# Input word1: government shutdowns
# Input word2: economy
# Predicted Label: impacts
#
# Input word1: storm
# Input word2: U.S.
# Predicted Label: impacts
#
# Input word1: economic expansion
# Input word2: borrowing costs
# Predicted Label: impacts
#
# Input word1: sequestration
# Input word2: industrial base and jobs
# Predicted Label: impacts
#
# Input word1: AstraZeneca
# Input word2: generic competition
# Predicted Label: sells
#
# Input word1: typhoon
# Input word2: emergency mission
# Predicted Label: impacts
#
# Input word1: Congress
# Input word2: Restrictions, PCAOB, substandard audits
# Predicted Label: offers
#
# Input word1: Alaska
# Input word2: Wind, geothermal, solar power
# Predicted Label: invests
#
# Input word1: Detour Gold
# Input word2: Paulson & Co
# Predicted Label: invests
#
# Input word1: investors
# Input word2: acquisitions
# Predicted Label: invests
#
# Input word1: Investors
# Input word2: Societe Generale
# Predicted Label: invests
#
# Input word1: LVMH
# Input word2: Designer's brand, investment
# Predicted Label: invests
#
# Input word1: Foreign investors
# Input word2: Chinese government bonds
# Predicted Label: invests
#
# Input word1: yield
# Input word2: Investors
# Predicted Label: invests
#
# Input word1: Uber
# Input word2: research and development
# Predicted Label: invests
#
# Input word1: fink
# Input word2: personal wealth
# Predicted Label: invests
#
# Input word1: Goldman Sachs
# Input word2: merchant bank
# Predicted Label: sells
#
# Input word1: International investors
# Input word2: Indian shares
# Predicted Label: sells
#
# Input word1: investor
# Input word2: hotel IPOs
# Predicted Label: invests
#
# Input word1: Carlos Jesus
# Input word2: difference
# Predicted Label: invests
#
# Input word1: Technip
# Input word2: Ghana
# Predicted Label: invests
#
# Input word1: Like Buffett, Alwaleed
# Input word2: Apple Inc. and News Corp
# Predicted Label: sells
#
# Input word1: Foxconn's Hon Hai Precision
# Input word2: machine tool automation
# Predicted Label: invests
#
# Input word1: Guggenheim's insurance arms
# Input word2: Dodgers
# Predicted Label: invests
#
# Input word1: investing
# Input word2: $9,000
# Predicted Label: invests
#
# Input word1: clients
# Input word2: Kazakhstan
# Predicted Label: invests
#
# Input word1: Foxconn
# Input word2: manufacturing unit
# Predicted Label: invests
#
# Input word1: S. Bernanke
# Input word2: DoubleLine Capital LP
# Predicted Label: represents
#
# Input word1: Investors
# Input word2: Bordeaux wines
# Predicted Label: invests
#
# Input word1: Volkswagen
# Input word2: Bernd Osterloh
# Predicted Label: invests
#
# Input word1: pension
# Input word2: alternative investments,
# Predicted Label: manages
#
# Input word1: Namdeb
# Input word2: technology
# Predicted Label: invests
#
# Input word1: investors
# Input word2: the accord
# Predicted Label: generates
#
# Input word1: Developers
# Input word2: Agile and Soho China
# Predicted Label: invests
#
# Input word1: government
# Input word2: funds
# Predicted Label: invests
#
# Input word1: investors
# Input word2: yield
# Predicted Label: invests
#
# Input word1: Quebec
# Input word2: Monaco
# Predicted Label: invests
#
# Input word1: investors
# ...
# Input word2: paintiffs
# Predicted Label: represents
#
# Input word1: Federal Borrowing
# Input word2: new lending
# Predicted Label: represents
#
# Input word1: Lehmann
# Input word2: law sponsored by Representatives
# Predicted Label: represents
#
# Input word1: third-quarter
# Input word2: true-up
# Predicted Label: represents
#
# Input word1: Unions and groups
# Input word2: retired workers
# Predicted Label: represents
#
# Input word1: Winnipeg-based association
# Input word2: grain-handlers
# Predicted Label: represents
#
# Input word1: Catherine Ashton
# Input word2: six world powers
# Predicted Label: represents
#
# Input word1: Swedish Competition
# Input word2: 19 percent premium
# Predicted Label: sells
#
# Input word1: Galdino e Carneiro Advogados
# Input word2: OSX
# Predicted Label: represents
#
# Input word1: UT
# Input word2: minority students
# Predicted Label: provides
#
# Input word1: Michael Keating
# Input word2: Ropes & Gray
# Predicted Label: represents
#
# Input word1: Angela Hartnett
# Input word2: signature dishes of nominees
# Predicted Label: creates
#
# Input word1: Mercury
# Input word2: brands
# Predicted Label: represents
#
# Input word1: director
# Input word2: companies
# Predicted Label: invests
#
# Input word1: Credit insurance
# Input word2: more than half of income
# Predicted Label: represents
#
# Input word1: The union
# Input word2: IRS workers
# Predicted Label: represents
#
# Input word1: Renewable Fuels Association
# Input word2: ethanol makers
# Predicted Label: represents
#
# Input word1: Dave Camp
# Input word2: House Ways and Means Committee
# Predicted Label: represents
#
# Input word1: They
# Input word2: less of the shares
# Predicted Label: represents
#
# Input word1: Christine Farnish
# Input word2: Peer-to-Peer Finance Association, a trade group representing crowd-funding platforms
# Predicted Label: manages
#
# Input word1: Democratic senator or representative
# Input word2: the list of those calling for delaying the mandate
# Predicted Label: represents
#
# Input word1: Swiss regulator
# Input word2: shipments
# Predicted Label: represents
#
# Input word1: Smith
# Input word2: investors
# Predicted Label: represents
#
# Input word1: Investment Management Association
# Input word2: fund industry
# Predicted Label: represents
#
# Input word1: The BDI industry lobby
# Input word2: 100,000 companies says energy costs threaten jobs and investment.
# Predicted Label: represents
#
# Input word1: Congress since 1992
# Input word2: district
# Predicted Label: represents
#
# Input word1: personnel costs
# Input word2: spending
# Predicted Label: represents
#
# Input word1: figure
# Input word2: estimate
# Predicted Label: represents
#
# Input word1: lawyer
# Input word2: AgFeed
# Predicted Label: generates
#
# Input word1: deal
# Input word2: 39 percent premium
# Predicted Label: represents
#
# Input word1: the Senate and the House of Representatives
# Input word2: halting the government shutdown and raising the U.S. debt limit
# Predicted Label: represents
#
# Input word1: Steve Southerland
# Input word2: Florida
# Predicted Label: impacts
#
# Input word1: U.S. Chamber of Commerce, Michigan Chamber of Commerce
# Input word2: Fred Upton
# Predicted Label: represents
#
# Input word1: Waterways Council
# Input word2: barge companies, ports, labor unions, farm groups and tugboats
# Predicted Label: represents
#
# Input word1: Bill Huizenga
# Input word2: Michigan
# Predicted Label: creates
#
# Input word1: Eliot Engel
# Input word2: Campbell
# Predicted Label: represents
#
# Input word1: 63.2 percent last year
# Input word2: 353 million prescriptions,
# Predicted Label: represents
#
# Input word1: UBS AG
# Input word2: quality of the loans
# Predicted Label: represents
#
# Input word1: Amir-Mokri
# Input word2: clients
# Predicted Label: represents
#
# Input word1: Jonathan Laidlaw
# Input word2: Brooks
# Predicted Label: represents
#
# Input word1: Union Sindical Obrera
# Input word2: workers
# Predicted Label: represents
#
# Input word1: interests
# Input word2: single case
# Predicted Label: represents
#
# Input word1: Charlie Dent
# Input word2: Washington Post
# Predicted Label: represents
#
# Input word1: non-bank lending
# Input word2: share
# Predicted Label: represents
#
# Input word1: Garodnick
# Input word2: Midtown district
# Predicted Label: represents
#
# Input word1: Jeff Holmstead
# Input word2: coal-heavy utilities
# Predicted Label: represents
#
# Input word1: Anouk
# Input word2: country
# Predicted Label: represents
#
# Input word1: Ginter
# Input word2: retired workers
# Predicted Label: represents
#
# Input word1: unit
# Input word2: 1.5 billion euros
# Predicted Label: represents
#
# Input word1: Magnetar's influence
# Input word2: portfolio, collateral for Octans I
# Predicted Label: invests
#
# Input word1: Galatioto
# Input word2: om Ricketts
# Predicted Label: represents
#
# Input word1: Attorney
# Input word2: Clients
# Predicted Label: represents
#
# Input word1: stores
# Input word2: market
# Predicted Label: represents
#
# Input word1: 18 plaintiffs
# Input word2: class of all investors
# Predicted Label: represents
#
# Input word1: Steny Hoyer
# Input word2: Maryland
# Predicted Label: represents
#
# Input word1: IMG
# Input word2: National Football League quarterback Peyton Manning and singer Taylor Swift
# Predicted Label: represents
#
# Input word1: John Engler
# Input word2: chief executives
# Predicted Label: represents
#
# Input word1: Patton Boggs LLP
# Input word2: plaintiffs in the Ecuador case
# Predicted Label: represents
#
# Input word1: The surcharge
# Input word2: amount of capital a bank must have beyond the minimums already set by international regulators
# Predicted Label: represents
#
# Input word1: union officials
# Input word2: pilots and flight attendants
# Predicted Label: represents
#
# Input word1: rated PG-13
# Input word2: more than half of top-grossing film revenue
# Predicted Label: generates
#
# Input word1: Chinese oil companies
# Input word2: giant Libra field
# Predicted Label: represents
#
# Input word1: Color of Change
# Input word2: African Americans' economic interests
# Predicted Label: represents
#
# Input word1: Bank of America Corp. and Citigroup Inc
# Input word2: Minmetals consortium,
# Predicted Label: represents
#
# Input word1: Pre-Sal Petroleo SA
# Input word2: government
# Predicted Label: represents
#
# Input word1: Unions representing more than 60 percent of workers
# Input word2: the Paris-based company
# Predicted Label: represents
#
# Input word1: Mike Rogers
# Input word2: House Permanent Select Committee on Intelligence
# Predicted Label: represents
#
# Input word1: $3.4 billion in 2012
# Input word2: more than 11 percent of Time Warner's total sales,
# Predicted Label: represents
#
# Input word1: Richard Hunt
# Input word2: Consumer Bankers Association
# Predicted Label: represents
#
# Input word1: JPMorgan
# Input word2: compensation of the unit's revenue
# Predicted Label: represents
#
# Input word1: no one person
# Input word2: city
# Predicted Label: represents
#
# Input word1: Representatives
# Input word2: visas
# Predicted Label: represents
#
# Input word1: people-centered
# Input word2: comprehensive economic, political, social and ecological reforms
# Predicted Label: represents
#
# Input word1: Lynn Westmoreland
# Input word2: Georgia
# Predicted Label: represents
#
# Input word1: Administrations
# Input word2: both sides of Thailand's political divide
# Predicted Label: represents
#
# Input word1: Labour's plan
# Input word2: starkest dividing line
# Predicted Label: represents
#
# Input word1: E-commerce
# Input word2: market
# Predicted Label: represents
#
# Input word1: District 751
# Input word2: Boeing workers
# Predicted Label: represents
#
# Input word1: The servicing rights, or MSRs
# Input word2: Citigroup's total contracts
# Predicted Label: represents
#
# Input word1: Mukhriz
# Input word2: UMNO
# Predicted Label: represents
#
# Input word1: Gordon Goldstein
# Input word2: Dell
# Predicted Label: represents
#
# Input word1: Jonathan Laidlaw
# Input word2: Brooks
# Predicted Label: represents
#
# Input word1: case
# Input word2: 620 pounds
# Predicted Label: sells
#
# Input word1: batista
# Input word2: eneva stake
# Predicted Label: sells
#
# Input word1: investors
# Input word2: stocks
# Predicted Label: sells
#
# Input word1: fiat
# Input word2: new shares
# Predicted Label: sells
#
# Input word1: Vringo
# Input word2: stock
# Predicted Label: sells
#
# Input word1: Aluminum Corporation of China Ltd.
# Input word2: stake
# Predicted Label: sells
#
# Input word1: GNC holding inc. and vitamin shoppe inc
# Input word2: dietry supplements
# Predicted Label: sells
#
# Input word1: caboinet
# Input word2: stakes
# Predicted Label: sells
#
# Input word1: government
# Input word2: stakes
# Predicted Label: sells
#
# Input word1: OSX hired Credit Suisse Group AG
# Input word2: vessels
# Predicted Label: sells
#
# Input word1: California
# Input word2: debt maturing
# Predicted Label: sells
#
# Input word1: Kinh Do office
# Input word2: products
# Predicted Label: sells
#
# Input word1: company
# Input word2: notes
# Predicted Label: sells
#
# Input word1: The Treasury
# Input word2: $21 billion of securities
# Predicted Label: sells
#
# Input word1: Alliander
# Input word2: notes
# Predicted Label: sells
#
# Input word1: farmers
# Input word2: land
# Predicted Label: sells
#
# Input word1: Gertler's Fleurette Group
# Input word2: stake
# Predicted Label: sells
#
# Input word1: O'key
# Input word2: swimmer
# Predicted Label: sells
#
# Input word1: Extended Stay
# Input word2: paired common stock
# Predicted Label: sells
#
# Input word1: Asian buyers
# Input word2: London homes
# Predicted Label: sells
#
# Input word1: North Sea Royal Dutch Shell Plc
# Input word2: Forties cargo F1203
# Predicted Label: sells
#
# Input word1: Citigroup
# Input word2: investments
# Predicted Label: sells
#
# Input word1: automaker
# Input word2: cars
# Predicted Label: sells
#
# Input word1: company
# Input word2: vehicles
# Predicted Label: sells
#
# Input word1: investors
# Input word2: local stocks
# Predicted Label: sells
#
# Input word1: investors
# Input word2: stocks
# Predicted Label: sells
#
# Input word1: Spain
# Input word2: debt
# Predicted Label: sells
#
# Input word1: Louis Vuitton
# Input word2: Purse
# Predicted Label: sells
#
# Input word1: SK Broadband Co.
# Input word2: U.S dollar bond
# Predicted Label: provides
#
# Input word1: Hertz Global Holdings Inc.
# Input word2: five-years securities
# Predicted Label: sells
#
# Input word1: Nintendo Co.
# Input word2: 3DS player
# Predicted Label: sells
#
# Input word1: Valeant Pharmaceuticals Internationa
# Input word2: eight-year senior bonds
# Predicted Label: sells
#
# Input word1: Health Warrior's
# Input word2: food energy
# Predicted Label: offers
#
# Input word1: Senate leaders
# Input word2: the plan to lawmaker
# Predicted Label: sells
#
# Input word1: house on Pollock's Path in The Peak area
# Input word2: HK$800 million in 2011
# Predicted Label: sells
#
# Input word1: Springleaf
# Input word2: 21 million shares
# Predicted Label: generates
#
# Input word1: India
# Input word2: spectrum
# Predicted Label: sells
#
# Input word1: Global funds
# Input word2: $87 million
# Predicted Label: sells
#
# Input word1: Economy repairing sareb
# Input word2: spain's recovery
# Predicted Label: sells
#
# Input word1: Traders
# Input word2: stocks
# Predicted Label: sells
#
# Input word1: Senate Leaders
# Input word2: Plan
# Predicted Label: sells
#
# Input word1: Telefonica
# Input word2: 69 percent stake
# Predicted Label: sells
#
# Input word1: Buffett
# Input word2: Exxon
# Predicted Label: sells
#
# Input word1: Canada Bread
# Input word2: goods
# Predicted Label: sells
#
# Input word1: Berkshire
# Input word2: Texas Competitive Electric Holdings Co.
# Predicted Label: sells
#
# Input word1: Lucio Fontana
# Input word2: contemporary art
# Predicted Label: sells
#
# Input word1: Vekselberg
# Input word2: stake
# Predicted Label: sells
#
# Input word1: businesses
# Input word2: products
# Predicted Label: sells
#
# Input word1: SolarCity
# Input word2: bonds
# Predicted Label: sells
#
# Input word1: Fairbank
# Input word2: shares
# Predicted Label: sells
#
# Input word1: Telecom Plus
# Input word2: energy companies
# Predicted Label: sells
#
# Input word1: producer
# Input word2: brazil
# Predicted Label: sells
#
# Input word1: Chateau Margaux
# Input word2: wines
# Predicted Label: sells
#
# Input word1: hassell
# Input word2: operational improvements
# Predicted Label: invests
#
# Input word1: Sareb's mission Sareb
# Input word2: soured property
# Predicted Label: sells
#
# Input word1: U.S.
# Input word2: debts
# Predicted Label: sells
#
# Input word1: Cadivi
# Input word2: dollars
# Predicted Label: sells
#
# Input word1: Lexus IS
# Input word2: car
# Predicted Label: sells
#
# Input word1: Zurich Insurance
# Input word2: entire stake
# Predicted Label: sells
#
# Input word1: Speculators
# Input word2: shares
# Predicted Label: sells
#
# Input word1: monetary authority
# Input word2: local dollar
# Predicted Label: sells
#
# Input word1: Reliance
# Input word2: fruits and clothes
# Predicted Label: sells
#
# Input word1: Tradekey
# Input word2: Fake Tradekey
# Predicted Label: sells
#
# Input word1: pre-Affordable Care Act
# Input word2: Vermont
# Predicted Label: sells
#
# Input word1: Swire Properties Ltd. last year
# Input word2: a unit in a Frank Gehry-designed building for HK$455 million
# Predicted Label: sells
#
# Input word1: Twitter
# Input word2: shares
# Predicted Label: provides
#
# Input word1: investors
# Input word2: risk positions
# Predicted Label: sells
#
# Input word1: france
# Input word2: notes
# Predicted Label: sells
#
# Input word1: Seville
# Input word2: shares
# Predicted Label: sells
#
# Input word1: Sequana
# Input word2: investment
# Predicted Label: sells
#
# Input word1: Country
# Input word2: power from renewable power plants
# Predicted Label: sells
#
# Input word1: Minelab Americas Inc.
# Input word2: metal-detecting equipment
# Predicted Label: sells
#
# Input word1: I
# Input word2: stocks
# Predicted Label: sells
#
# Input word1: The Model S, Tesla's only vehicle
# Input word2: $70,000 to more than $100,000
# Predicted Label: sells
#
# Input word1: Transocean
# Input word2: vessel
# Predicted Label: sells
#
# Input word1: Bayerische Motoren Werke
# Input word2: cars
# Predicted Label: sells
#
# Input word1: Lexus IS
# Input word2: car
# Predicted Label: sells
#
# Input word1: KBC Ancora
# Input word2: shares
# Predicted Label: sells
#
# Input word1: stake
# Input word2: Chinese manufacturer
# Predicted Label: sells
#
# Input word1: Telefonica SA
# Input word2: stake
# Predicted Label: sells
#
# Input word1: Homeowners
# Input word2: loans
# Predicted Label: sells
#
# Input word1: Directors
# Input word2: Stock
# Predicted Label: sells
#
# Input word1: bonds
# Input word2: Fannie
# Predicted Label: sells
#
# Input word1: ranchers
# Input word2: cattle
# Predicted Label: sells
#
# Input word1: Rosedale Aviation Holdings Ltd.
# Input word2: stake
# Predicted Label: sells
#
# Input word1: Issuers
# Input word2: bonds
# Predicted Label: sells
#
# Input word1: Sony
# Input word2: PlayStation
# Predicted Label: sells
#
# Input word1: central bank
# Input word2: repo contracts
# Predicted Label: sells
#
# Input word1: Third Point
# Input word2: shares of Sunnyvale
# Predicted Label: sells
#
# Input word1: U.K.
# Input word2: gilts
# Predicted Label: sells
#
# Input word1: Tudor
# Input word2: holdings
# Predicted Label: sells
#
# Input word1: foreign companies
# Input word2: shares
# Predicted Label: sells
#
# Input word1: Rovio
# Input word2: Angry birds
# Predicted Label: sells
#
# Input word1: The U.K oil and gas explorer
# Input word2: stakes
# Predicted Label: sells
#
# Input word1: Samsung
# Input word2: smartphone
# Predicted Label: sells
#
# Input word1: Reyal Urbis SA
# Input word2: ABC Serrano
# Predicted Label: sells
#
# Input word1: HBSC
# Input word2: stake
# Predicted Label: affects
#
# Input word1: WPP Sale
# Input word2: 10-year notes
# Predicted Label: sells
#
# Input word1: developer
# Input word2: yuan of properties
# Predicted Label: sells
#
# Input word1: women
# Input word2: hair, breast milk
# Predicted Label: sells
#
# Input word1: U.S. companies
# Input word2: bonds
# Predicted Label: sells
#
# Input word1: U.S.
# Input word2: bills and securities
# Predicted Label: sells
#
# Input word1: lender
# Input word2: mortgage bonds
# Predicted Label: sells
#
# Input word1: Ponce
# Input word2: potash industry
# Predicted Label: sells
#
# Input word1: Apple
# Input word2: phones
# Predicted Label: sells
#
# Input word1: Diageo
# Input word2: malt whiskies
# Predicted Label: sells
#
# Input word1: Pentagon Proposal
# Input word2: V-22 tiltrotor Aircraft
# Predicted Label: sells
#
# Input word1: Paintings
# Input word2: millions
# Predicted Label: sells
#
# Input word1: Captain Growth
# Input word2: 4.3 million shares of Hertz
# Predicted Label: sells
#
# Input word1: INA
# Input word2: potential sellers
# Predicted Label: sells

# %%
display(dfk)
# Out:
#         Id  Relation
# 0     8920   affects
# 1       64   affects
# 2     2755   affects
# 3     6871   affects
# 4     7305  involves
# ...    ...       ...
# 1315  8344     sells
# 1316  5943     sells
# 1317  4424     sells
# 1318  4457     sells
# 1319  6012     sells
#
# [1320 rows x 2 columns]

# %%
# saving the dataframe
dfk.to_csv(r'D:\Lithin\codlang3\Submission.csv')
